# %%
import matplotlib.pyplot as plt
import datetime
import matplotlib.patches as patches
import math
from sociophysicsDataHandler import SociophysicsDataHandler
import numpy as np

# %%
dh = SociophysicsDataHandler()

# %%
dh.fetch_background_image_from_path('ehv/background_images/EHV.Perron2.1_multisensor.png')
# Out:
# trying to fetch: /storage/surfsara/ProRail_USE_LL_data/ehv/background_images/EHV.Perron2.1_multisensor.png
# background fetched. Accessible as <this-object>.bg

# %%
plt.imshow(dh.bg,cmap='viridis')

# %%
fig = plt.figure(figsize=(20,8))
ax = fig.add_subplot(111)
plt.ax.imshow(dh.bg,cmap='viridis')
xmin = -5134
ymin = -17731
xmax =  75135
ymax =  11645
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [29], line 3
#       1 fig = plt.figure(figsize=(20,8))
#       2 ax = fig.add_subplot(111)
# ----> 3 plt.ax.imshow(dh.bg,cmap='viridis')
#       4 xmin = -5134
#       5 ymin = -17731
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ax'
